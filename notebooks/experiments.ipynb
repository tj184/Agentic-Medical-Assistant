# %%
from app.models.embeddings_model import EmbeddingModel

model = EmbeddingModel()

embedding = model.embed_text(
    "Chest pain and cough"
)

print(len(embedding))

# %%
from app.services.rag_service import RAGService

rag = RAGService()

result = rag.retrieve_medical_context(
    "Symptoms of diabetes"
)

print(result)

# %%
from app.graph.workflow import MedicalWorkflow

workflow = MedicalWorkflow()

result = workflow.run(
    patient_text=\"\"\"
    Patient has chest pain,
    shortness of breath,
    and dizziness
    \"\"\",
    medicines=[
        "Aspirin",
        "Warfarin"
    ]
)

print(result)

# %%
from app.models.llm import LLMModel

llm = LLMModel()

response = llm.generate_response(
    "What are the symptoms of pneumonia?"
)

print(response)
